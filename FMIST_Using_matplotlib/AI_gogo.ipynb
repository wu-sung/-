# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# %%
training_data = datasets.FashionMNIST(
    root='./data', train=True, download=True, transform=ToTensor()
)
test_data = datasets.FashionMNIST(
    root='./data', train=False, download=True,transform=ToTensor()
)

# %%
labels_map = {
    0: "T-shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",    
}
figure = plt.figure(figsize = (8,8))
cols, rows = 3,3
for i in range(1, cols*rows +1):
    sample_idx = torch.randint(len(training_data),size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows,cols,i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
training_data = datasets.CIFAR100(
    root='./data', train=True, download=True, transform=ToTensor()
)
test_data = datasets.CIFAR100(
    root='./data', train=False, download=True,transform=ToTensor()
)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data\cifar-100-python.tar.gz
# 1.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9724\3178537904.py in <module>
#       1 training_data = datasets.CIFAR100(
# ----> 2     root='./data', train=True, download=True, transform=ToTensor()
#       3 )
#       4 test_data = datasets.CIFAR100(
#       5     root='./data', train=False, download=True,transform=ToTensor()
#
# ~\AppData\Roaming\Python\Python37\site-packages\torchvision\datasets\cifar.py in __init__(self, root, train, transform, target_transform, download)
#      64
#      65         if download:
# ---> 66             self.download()
#      67
#      68         if not self._check_integrity():
#
# ~\AppData\Roaming\Python\Python37\site-packages\torchvision\datasets\cifar.py in download(self)
#     142             print('Files already downloaded and verified')
#     143             return
# --> 144         download_and_extract_archive(self.url, self.root, filename=self.filename, md5=self.tgz_md5)
#     145
#     146     def extra_repr(self) -> str:
#
# ~\AppData\Roaming\Python\Python37\site-packages\torchvision\datasets\utils.py in download_and_extract_archive(url, download_root, extract_root, filename, md5, remove_finished)
#     425         filename = os.path.basename(url)
#     426
# --> 427     download_url(url, download_root, filename, md5)
#     428
#     429     archive = os.path.join(download_root, filename)
#
# ~\AppData\Roaming\Python\Python37\site-packages\torchvision\datasets\utils.py in download_url(url, root, filename, md5, max_redirect_hops)
#     138         try:
#     139             print('Downloading ' + url + ' to ' + fpath)
# --> 140             _urlretrieve(url, fpath)
#     141         except (urllib.error.URLError, IOError) as e:  # type: ignore[attr-defined]
#     142             if url[:5] == 'https':
#
# ~\AppData\Roaming\Python\Python37\site-packages\torchvision\datasets\utils.py in _urlretrieve(url, filename, chunk_size)
#      35                     if not chunk:
#      36                         break
# ---> 37                     pbar.update(chunk_size)
#      38                     fh.write(chunk)
#      39
#
# ~\AppData\Roaming\Python\Python37\site-packages\torch\hub.py in update(self, n)
#      40                 else:
#      41                     sys.stderr.write("\r{0:.1f}%".format(100 * self.n / float(self.total)))
# ---> 42                 sys.stderr.flush()
#      43
#      44             def close(self):
#
# F:\poi\envs\choi\lib\site-packages\ipykernel\iostream.py in flush(self)
#     486             self.pub_thread.schedule(evt.set)
#     487             # and give a timeout to avoid
# --> 488             if not evt.wait(self.flush_timeout):
#     489                 # write directly to __stderr__ instead of warning because
#     490                 # if this is happening sys.stderr may be the problem.
#
# F:\poi\envs\choi\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# F:\poi\envs\choi\lib\threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
labels_map = {
    0: "Airplane",
    1: "Automobile",
    2: "Bird",
    3: "Cat",
    4: "Deer",
    5: "Dog",
    6: "Frog",
    7: "Horse",
    8: "Ship",
    9: "Truck",    
}
figure = plt.figure(figsize = (16,16))
cols, rows = 10,10
for i in range(1, cols*rows +1):
    sample_idx = torch.randint(len(training_data),size=(1,)).item()
    img, label = training_data[sample_idx]
    img = img.permute(1,2,0) # (0 -channel, 1 -width, 2 -height) -> (1, 2, 0) 
    figure.add_subplot(rows,cols,i)
    plt.title(labels_map[label], y = 0.11)
    plt.axis("off")
    plt.imshow(img)
plt.show()

# %%
import numpy as np

# 빈 딕셔너리 생성 직접 생성
data= dict()

# 32x32 배열을 1000개 생성 (0에서 1난수 생성)
data['x'] = np.random.rand(1000,32,32)
print(f"data : {data['x']}")

#0~9의 난수를 발생시키고 1000개 생성
data['y'] = np.random.randint(10, size =1000)
print(f"data : {data['y']}")
# Out:
# data : [[[0.88088121 0.36691268 0.51746573 ... 0.65143729 0.93108104 0.7766283 ]
#   [0.93743375 0.17471641 0.28558379 ... 0.72177529 0.69830028 0.84458697]
#   [0.1363105  0.02797337 0.4783516  ... 0.70126766 0.20289696 0.38770947]
#   ...
#   [0.08265705 0.96612541 0.23761117 ... 0.83971882 0.38460524 0.52760077]
#   [0.04556417 0.96272092 0.89466712 ... 0.00621907 0.33804447 0.06647833]
#   [0.20476476 0.53400173 0.87259547 ... 0.04892948 0.48879005 0.27930842]]
#
#  [[0.38853919 0.07734537 0.99237036 ... 0.39300317 0.59889176 0.12097373]
#   [0.64002314 0.83932563 0.30858401 ... 0.36165612 0.8549775  0.10498229]
#   [0.56199531 0.06391372 0.47199653 ... 0.75705043 0.69328343 0.80284009]
#   ...
#   [0.63629269 0.12476534 0.90405394 ... 0.97423844 0.9235985  0.39536538]
#   [0.80084103 0.21606326 0.30638045 ... 0.4788431  0.65340449 0.41737884]
#   [0.60172635 0.90819718 0.31319372 ... 0.75438144 0.78150885 0.35129961]]
#
#  7 4 1 8 7 7 5 8 1 3 7 2 5 1 4 2 4 6 0 8 1 8 6 7 4 8 1 2 8 3 0 4 8 7 7 4 0
#  3 4 6 3 3 9 9 8 6 2 0 9 6 8 6 0 7 8 4 4 2 6 9 0 7 6 9 1 6 8 0 2 5 9 7 4 3
#  5 4 3 7 6 2 7 2 6 8 1 7 5 8 2 0 1 0 6 0 9 1 3 7 0 8 5 8 4 6 9 6 7 5 8 6 7
#  0]

# %%
class MyDataset(Dataset):
    def __init__(self, raw_data):
        self.x = torch.from_numpy(raw_data['x'])
        self.y = torch.from_numpy(raw_data['y'])
        
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, idx):
        print("idx : {}".format(idx))
        return self.x[idx], self.y[idx]

# %%
class MyDataset2(Dataset):
    def __init__(self, raw_data):
        self.x = torch.from_numpy(raw_data['x'])
        self.y = torch.from_numpy(raw_data['y'])
        
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        print("idx : {}".format(idx))
        return self.x[idx], self.y[idx], len(self)

# %%
my_dataset = MyDataset(data)
for x, y in my_dataset:
    print(x, y)
    print(x.size())
    break
# Out:
# idx : 0
# tensor([[0.8809, 0.3669, 0.5175,  ..., 0.6514, 0.9311, 0.7766],
#         [0.9374, 0.1747, 0.2856,  ..., 0.7218, 0.6983, 0.8446],
#         [0.1363, 0.0280, 0.4784,  ..., 0.7013, 0.2029, 0.3877],
#         ...,
#         [0.0827, 0.9661, 0.2376,  ..., 0.8397, 0.3846, 0.5276],
#         [0.0456, 0.9627, 0.8947,  ..., 0.0062, 0.3380, 0.0665],
#         [0.2048, 0.5340, 0.8726,  ..., 0.0489, 0.4888, 0.2793]],
#        dtype=torch.float64) tensor(8, dtype=torch.int32)
# torch.Size([32, 32])

# %%
my_dataset2 = MyDataset2(data)
for x, y, length in my_dataset2:
    print(x, y, length)
    break
# Out:
# idx : 0
# tensor([[0.8809, 0.3669, 0.5175,  ..., 0.6514, 0.9311, 0.7766],
#         [0.9374, 0.1747, 0.2856,  ..., 0.7218, 0.6983, 0.8446],
#         [0.1363, 0.0280, 0.4784,  ..., 0.7013, 0.2029, 0.3877],
#         ...,
#         [0.0827, 0.9661, 0.2376,  ..., 0.8397, 0.3846, 0.5276],
#         [0.0456, 0.9627, 0.8947,  ..., 0.0062, 0.3380, 0.0665],
#         [0.2048, 0.5340, 0.8726,  ..., 0.0489, 0.4888, 0.2793]],
#        dtype=torch.float64) tensor(8, dtype=torch.int32) 1000

# %%
my_list = [1, 2, 3, 4, 5]

# 리스트를 이터레이터로 변환
my_iterator = iter(my_list)

# 이터레이터에서 값을 가져오기
print(next(my_iterator))  # 1
print(next(my_iterator))  # 2
print(next(my_iterator))  # 3

for value in my_iterator:
    print(value)
# Out:
# 1
# 2
# 3
# 4
# 5
